# %% [markdown]
# # Santa Ana Winds Indicators Notebook

# %% [markdown]
# Santa Ana winds are intense dry winds that blow from the Mojave Desert downslope to the Southern California coast (Seto et al. 2025). These winds are driven by a high pressure system over Mojave High Desert that rotates clockwise toward low-pressure off the California Coast. As the air descends the high desert toward the coast, it goes through dry adiabatic warming as it traverses narrow mountain canyons and passes. This process is known as the Venturi effect, where the air sinks, compresses, warms, dries out and speeds up. This creates incredibly dry air at dramatically increased wind speeds. Santa Ana wind occurrence generally peaks in December, with a season that generally spans October-March (Abel and Hall 2010). Upper level temperature and winds, along with the gradient in sea level pressure, can be used to identify conditions that support Santa Ana Wind occurrence.
#
# This notebook allows users to generate hourly timeseries of indicator variables for Santa Ana winds, including upper level temperature gradient, upper level winds, and sea level pressure gradient. By default two points, one in the Mojave Desert and one in Santa Monica, are used to compare these indicators. These results can then be used as inputs in the Event Finder notebook to identify timepoints where these indicators exceed a threshold.
#
# **Intended Application:** As a user, I want to <span style="color:#FF0000">generate hourly timeseries of key Santa Ana Wind indicators: upper level temperature gradient, upper level winds, and sea level pressure gradient.
# </span>
#
# **Runtime:** On the Analytics Engine Jupyter Hub platform this notebook will take approximately **30 minutes** to run using the default settings.
#
# **Notes:** This is a prototype notebook. Currently only 1 simulation is available for geopotential height.
#
# **References:**
#
# Abel, M.R., and A. Hall, 2010: Local and synoptic mechanisms causing Southern California’s Santa Ana winds. Clim Dyn 34, 847–857, https://doi.org/10.1007/s00382-009-0650-4
#
# Seto, D., C. Jones, D. Siuta, N. Wagenbrenner, C. Thompson, and N. Quinn, 2025: Evaluation of HRRR Wind Speed Forecast and WindNinja Downscaling Accuracy during Santa Ana Wind Events in Southern California. Wea. Forecasting, 40, 525–541, https://doi.org/10.1175/WAF-D-24-0013.1.

# %% [markdown]
# # Setup
# ### Environment

# %% [markdown]
# This notebook requires two packages which are not part of the standard climakitae environment. These are `h5netcdf` and `windrose`. These packages will be installed when the following cell is run:

# %%
# !pip install h5netcdf
# !pip install windrose
# Out:
# Requirement already satisfied: h5netcdf in /home/jovyan/.local/lib/python3.12/site-packages (1.8.1)
# Requirement already satisfied: packaging in /home/jovyan/.local/lib/python3.12/site-packages (from h5netcdf) (26.0)
# Requirement already satisfied: numpy in /home/jovyan/.local/lib/python3.12/site-packages (from h5netcdf) (2.3.5)
# Requirement already satisfied: windrose in /home/jovyan/.local/lib/python3.12/site-packages (1.9.2)
# Requirement already satisfied: matplotlib>=3 in /home/jovyan/.local/lib/python3.12/site-packages (from windrose) (3.10.8)
# Requirement already satisfied: numpy>=1.21 in /home/jovyan/.local/lib/python3.12/site-packages (from windrose) (2.3.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jovyan/.local/lib/python3.12/site-packages (from matplotlib>=3->windrose) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jovyan/.local/lib/python3.12/site-packages (from matplotlib>=3->windrose) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jovyan/.local/lib/python3.12/site-packages (from matplotlib>=3->windrose) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jovyan/.local/lib/python3.12/site-packages (from matplotlib>=3->windrose) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/jovyan/.local/lib/python3.12/site-packages (from matplotlib>=3->windrose) (26.0)
# Requirement already satisfied: pillow>=8 in /home/jovyan/.local/lib/python3.12/site-packages (from matplotlib>=3->windrose) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/jovyan/.local/lib/python3.12/site-packages (from matplotlib>=3->windrose) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib>=3->windrose) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3->windrose) (1.17.0)

# %% [markdown]
# Import the remaining dependencies:

# %%
import climakitae as ck
from climakitae.core.constants import WRF_CRS
from climakitae.core.data_export import export
from climakitae.core.data_load import load
from climakitae.new_core.processors.warming_level import WarmingLevel
from climakitae.util.utils import add_dummy_time_to_wl, get_closest_gridcell
from climakitae.tools.derived_variables import (
    compute_wind_dir,
    compute_sea_level_pressure,
    compute_geostrophic_wind,
)

import numpy as np
import s3fs
import xarray as xr
from matplotlib import cm, rc_context
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import windrose

# %% [markdown]
# ### Choose points
# For Santa Ana wind analysis, `gradient_point_1` would typically be a location near the Southern California coast, while `gradient_point_2` would be a location in the Mojave desert.
# When a gradient variable is calculated, the value at `gradient_point_2` will be subtracted from the value at `gradient_point_1`. This is done for upper level temperature and sea level pressure. A mean of the two points will be taken for the upper level wind speed evaluation.

# %%
gradient_point_1 = (34.031899244954694, -118.47507877286985)  # Santa Monica
gradient_point_2 = (34.31392420709518, -116.16003299789273)  # Mojave Desert

# %% [markdown]
# ### Choose global warming levels
# With this prototype dataset, only warming levels 0.8 and 1.5 can be used for upper level winds and temperature. Any valid warming level may be selected for sea level pressure only.

# %%
baseline_gwl = 0.8
future_gwl = 1.5

# %% [markdown]
# # Temperature and Geostrophic Wind

# %% [markdown]
# ## 1. Get Warming Levels

# %% [markdown]
# Access the WRF data for temperature and geopotential height and convert to warming levels.

# %%
hist_path = "s3://santa-ana-winds/miroc6_r1i1p1f1_historical/d01/temperature_geopotential_plevs.zarr"
ssp370_path = "s3://santa-ana-winds/miroc6_r1i1p1f1_ssp370/d01/temperature_geopotential_plevs.zarr/"

ds_hist = xr.open_dataset(
    hist_path, consolidated=True, zarr_format=2, engine="zarr", chunks={}
)
ds_ssp370 = xr.open_dataset(
    ssp370_path, consolidated=True, zarr_format=2, engine="zarr", chunks={}
)

ds_hist = ds_hist.sel(time=slice("1980-09-01", "2013-12-31 23:00"))
ds_ssp370 = ds_ssp370.sel(time=slice("2014-01-01", "2066-08-04 13:00"))

ds_hist = ds_hist.expand_dims({"member_id": ["r1i1p1f1"]})
ds_ssp370 = ds_ssp370.expand_dims({"member_id": ["r1i1p1f1"]})

ds_hist = ds_hist.convert_calendar("noleap")
ds_ssp370 = ds_ssp370.convert_calendar("noleap")

# Get warming levels
values = {
    "warming_levels": [baseline_gwl, future_gwl],
    "warming_level_months": [x for x in range(1, 13)],
}
WL = WarmingLevel(values)

data = {}
data["WRF.UCLA.MIROC6.ssp370.1hr.d03"] = ds_ssp370
data["WRF.UCLA.MIROC6.historical.1hr.d03"] = ds_hist

context = {"activity_id": "WRF"}
wls = WL.execute(data, context)

ds_wl = wls["WRF.UCLA.MIROC6.ssp370.1hr.d03.r1i1p1f1"]

ds_wl.attrs["frequency"] = "1hr"
ds_wl = add_dummy_time_to_wl(ds_wl)
ds_wl = ds_wl.expand_dims("sim", axis=0)
ds_wl = ds_wl.assign_coords(
    {"sim": ["WRF.UCLA.MIROC6.ssp370.1hr.d03.r1i1p1f1".replace(".", "_")]}
)

# %% [markdown]
# ## 2. Temperature gradient

# %% [markdown]
# Find the upper level temperature at the two points of interest and get the difference. Run the cell below to calculate this difference and write the results to file.
#
# This cell may take 5+ minutes to execute depending on your compute environment.

# %%
# Select a pressure level before computing the magnitude and direction of the geostrophic wind.
# Valid levels are 1000, 925, 850, 700, 500, 300, or 200. The default value is 850-200 hPa.
levels = [850, 700, 500, 300, 200]

# Get the temperature difference at selected levels
print("Getting temperature at each point.")
temperature = ds_wl["temperature"].sel(pressure_level=levels)

temp_pt_1 = get_closest_gridcell(
    temperature, gradient_point_1[0], gradient_point_1[1]
).compute()
temp_pt_2 = get_closest_gridcell(
    temperature, gradient_point_2[0], gradient_point_2[1]
).compute()

print("Calculating difference.")
temperature_diff = temp_pt_1 - temp_pt_2
temperature_diff.name = "temperature_gradient"
temperature_diff.attrs["long_name"] = "Temperature Gradient on Pressure Level"

print("Writing results to file.")
# Export hourly data, with each level as a separate file:
export(
    temperature_diff,
    f"temperature_gradient",
    format="NetCDF",
    mode="local",
)

# %% [markdown]
# This figure shows the temperature gradient at the selected level for each warming level at the selected pressure level (default is 850 hPa).

# %%
# Pick a pressure level to display
plot_level = 850  # hPa

f, ax = plt.subplots(1, 2, figsize=(10, 4))
plt.rcParams.update(
    {
        "grid.color": "0.5",  # gray gridlines
        "grid.linestyle": "--",  # solid gridlines
        "grid.linewidth": 0.5,  # thin gridlines
    }
)


temperature_diff.sel(warming_level=baseline_gwl, pressure_level=plot_level).plot(
    ax=ax[0]
)
ax[0].set_title(f"GWL {baseline_gwl}°C")
ax[0].set_ylim([-15, 20])
ax[0].set_xlim([temperature_diff.time[0].data, temperature_diff.time[-1].data])
ax[0].grid(True)

temperature_diff.sel(warming_level=future_gwl, pressure_level=plot_level).plot(ax=ax[1])
ax[1].set_title(f"GWL {future_gwl}°C")
ax[1].set_ylim([-15, 20])
ax[1].set_xlim([temperature_diff.time[0].data, temperature_diff.time[-1].data])
ax[1].grid(True)

plt.suptitle(f"Gradient of {plot_level} hPa temperature")
plt.tight_layout()
plt.savefig(f"temperature_gradient_{plot_level}hPa_by_gwl.png")

# %% [markdown]
# ## 3. Wind on Pressure Levels
# In this section we use the geostrophic wind equation to calculate the upper level wind on pressure levels at a point in between the two points of interest.

# %% [markdown]
# In the cell below, assign a pressure level in hectopascal (hPa) units to the `level` variable.

# %%
# Select a pressure level before computing the magnitude and direction of the geostrophic wind.
# Valid levels are 1000, 925, 850, 700, 500, 300, or 200. The default value is 850-200 hPa.
levels = [850]

# %% [markdown]
# Now run the following cell to save geostrophic wind magnitude and direction timeseries files for this level. This cell may take 10+ minutes to execute depending on your compute environment.

# %%
# The geostrophic wind will be calculated for each point for the selected level.
for point_ind, point in enumerate([gradient_point_1, gradient_point_2]):
    print(f"Working on point {point_ind+1}")

    # Pull out the selected pressure level
    print(f"Calculating geostrophic wind for levels {levels}")
    geopotential_height = ds_wl["geopotential_height"].sel(pressure_level=levels)

    # Get the geostrophic wind components at this point
    geo_wind_u_earth, geo_wind_v_earth = compute_geostrophic_wind(geopotential_height)

    print("Calculating magnitude and direction.")
    # Extract timeseries for just the point of interest
    geo_u_level = load(
        get_closest_gridcell(geo_wind_u_earth, point[0], point[1]), progress_bar=True
    )
    geo_v_level = load(
        get_closest_gridcell(geo_wind_v_earth, point[0], point[1]), progress_bar=True
    )

    # Calculate magnitude
    magnitude = np.sqrt(geo_u_level**2 + geo_v_level**2)
    magnitude.name = "magnitude"
    magnitude.attrs["long_name"] = "Geostrophic Wind Magnitude"
    magnitude.attrs["units"] = "m/s"

    # Calculate direction
    direction = compute_wind_dir(geo_u_level, geo_v_level)
    direction.name = "direction"
    direction.attrs["long_name"] = "Geostrophic Wind Direction"
    # Don't need to add units manually; units were added by compute_wind_dir

    print("Saving results to file.")
    # Export the timeseries for this level to file. Using the default settings, each of these files is
    # approximately 4 Mb in size (30 years of hourly data for two warming levels).
    export(
        magnitude,
        f"geostrophic_wind_magnitude_point_{point_ind+1}",
        format="NetCDF",
        mode="local",
    )
    export(
        direction,
        f"geostrophic_wind_direction_point_{point_ind+1}",
        format="NetCDF",
        mode="local",
    )
    del geo_u_level, geo_v_level, magnitude, direction
    print("\n")

# Finally, reload the magnitude timeseries and find the average of the
# wind speed at the two points.
print(f"Calculating 2-point mean wind magnitude for levels {levels}.")
magnitude_1 = xr.open_dataset(f"geostrophic_wind_magnitude_point_1.nc")
magnitude_2 = xr.open_dataset(f"geostrophic_wind_magnitude_point_2.nc")
magnitude_mean = (magnitude_1 + magnitude_2) / 2
export(
    magnitude_mean,
    f"geostrophic_wind_magnitude_point_mean",
    format="NetCDF",
    mode="local",
)

print("\nDone with geostrophic wind.")
# Out:
# Working on point 1
# Calculating geostrophic wind for levels [850]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       5 # Pull out the selected pressure level
#       6 print(f"Calculating geostrophic wind for levels {levels}")
# ----> 7 geopotential_height = ds_wl["geopotential_height"].sel(pressure_level=levels)
#       9 # Get the geostrophic wind components at this point
#      10 geo_wind_u_earth, geo_wind_v_earth = compute_geostrophic_wind(geopotential_height)
#
# NameError: name 'ds_wl' is not defined

# %% [markdown]
# Optionally, this code can be used to visualize the upper level wind results.

# %%
plot_level = 850

f, ax = plt.subplots(1, 2, figsize=(10, 4))
plt.rcParams.update(
    {
        "grid.color": "0.5",  # gray gridlines
        "grid.linestyle": "--",  # solid gridlines
        "grid.linewidth": 0.5,  # thin gridlines
    }
)

magnitude = xr.open_dataset(f"geostrophic_wind_magnitude_point_mean.nc")
magnitude["magnitude"].sel(warming_level=baseline_gwl, pressure_level=plot_level).plot(
    ax=ax[0]
)
ax[0].set_title(f"GWL {baseline_gwl}°C")
ax[0].set_ylim([0, 70])
ax[0].set_xlim([magnitude.time[0].data, magnitude.time[-1].data])
ax[0].grid(True)

magnitude["magnitude"].sel(warming_level=future_gwl, pressure_level=plot_level).plot(
    ax=ax[1]
)
ax[1].set_title(f"GWL {future_gwl}°C")
ax[1].set_ylim([0, 70])
ax[1].set_xlim([magnitude.time[0].data, magnitude.time[-1].data])
ax[1].grid(True)

plt.suptitle(f"Point mean {plot_level} hPa wind magnitude")
plt.tight_layout()
plt.savefig(f"wind_mean_magnitude_{plot_level}hPa_by_gwl.png")

# %% [markdown]
# The following cell will generate wind roses for point 1 and point 2.
#
# The wind direction at `gradient_point_1` (coast) can indicate if the wind is blowing offshore or not. In this case, the wind vector direction indicates the direction from which the wind blows, following meteorological convention (0-180° being an easterly wind).

# %%
plot_level = 850
plot_gwl = baseline_gwl

for point_ind in [1, 2]:
    wd_data = xr.open_dataset(f"geostrophic_wind_direction_point_{point_ind}.nc").sel(
        pressure_level=plot_level, warming_level=plot_gwl
    )["direction"]
    ws_data = xr.open_dataset(f"geostrophic_wind_magnitude_point_{point_ind}.nc").sel(
        pressure_level=plot_level, warming_level=plot_gwl
    )["magnitude"]

    title = f"{plot_level}hPa Wind Rose at Point {point_ind}"
    rmax = 24  # Max percent displayed
    rs = 6  # Percent spacing
    bins = np.arange(0, 18, 3)  # Wind speed bins

    rcParams = {
        "figure.figsize": (6, 6),
        "figure.facecolor": "white",
        "axes.facecolor": "lightgrey",
        "axes.edgecolor": "white",
        "grid.color": "white",
    }

    with rc_context(rcParams):
        fig, ax = plt.subplots(subplot_kw={"projection": "windrose"})

        ax.bar(
            wd_data.values.ravel(),
            ws_data.values.ravel(),
            bins=bins,
            cmap=cm.plasma,
            normed=True,
            opening=0.8,
            edgecolor="none",
            alpha=1,
            calm_limit=None,
        )

        # Fix patch layering
        minzorder = min(
            [c.get_zorder() for c in ax.get_children() if isinstance(c, Rectangle)]
        )

        for child in ax.get_children():
            if isinstance(child, Rectangle):
                zorder = child.get_zorder()
                child.set_zorder(3 + (zorder - minzorder))

        # Set labels
        labels = [
            "E",
            "ENE",
            "NE",
            "NNE",
            "N",
            "NNW",
            "NW",
            "WNW",
            "W",
            "WSW",
            "SW",
            "SSW",
            "S",
            "SSE",
            "SE",
            "ESE",
        ]

        # Set theta grid locations every 11.25 degrees
        angles = np.arange(0, 360, 45 / 2)
        ax.set_thetagrids(angles, labels, fontsize=10)

        ax.set_title(title)
        ax.set_legend(loc=4)

        # Set consistent magnitude scale
        ax.set_rmax(rmax)
        ticks = np.arange(rs, rmax + rs, rs, dtype="int")
        ax.set_yticks(ticks)
        ax.set_yticklabels([f"{p}%" for p in ticks])

        plt.show()

        plt.tight_layout()
        fig.savefig(f"wind_rose_point_{point_ind}_{plot_level}hPa_{plot_gwl.replace(".","pt"}.png")

# %% [markdown]
# # Sea Level Pressure

# %% [markdown]
# Sea level is computed using surface pressure, air temperature, and mixing ratio. Then the difference between two points is calculated and saved to file.
#
# ### Setup
# Choose the time frequency in the cell below. This section will use the warming levels and locations selected in the "Setup" section at the top of the notebook.

# %%
frequency = "1hr"  # 1hr or day

# %% [markdown]
# This function will handle the sea level pressure calculation for the selection gridpoints.

# %%
def get_slp_at_point(
    psfc: xr.DataArray,
    t2: xr.DataArray,
    q2: xr.DataArray,
    elevation: xr.DataArray,
    point: tuple[float],
) -> xr.DataArray:
    """Extract point of interest and return sea level pressure at that point.

    This function uses the default settings for `compute_sea_level_pressure`
    including for lapse rate.

    Parameters
    ----------
        surface_pressure : xr.DataArray
            Surface pressure in Pascals
        air_temperature : xr.DataArray
            Surface air temperature in Kelvin
        mixing_ratio : xr.DataArray
            Surface mixing ratio
        elevation : xr.DataArray
            Elevation in meters

    Returns
    -------
    xr.DataArray
        Sea level pressure in Hectopascals
    """

    # Extract data at point of interest
    print("Selecting point from input arrays.")
    psfc_pt = get_closest_gridcell(psfc.rio.write_crs(WRF_CRS), point[0], point[1])
    t2_pt = get_closest_gridcell(t2.rio.write_crs(WRF_CRS), point[0], point[1])
    q2_pt = get_closest_gridcell(q2.rio.write_crs(WRF_CRS), point[0], point[1])
    elev_pt = get_closest_gridcell(elevation.rio.write_crs(WRF_CRS), point[0], point[1])

    print("Calculating sea level pressure.")
    if frequency == "1hr":
        slp_pt = compute_sea_level_pressure(psfc_pt, t2_pt, q2_pt, elev_pt)
        slp_pt.attrs["frequency"] = "hourly"
    else:
        slp_pt = compute_sea_level_pressure(
            psfc_pt, t2_pt, q2_pt, elev_pt, average_t2=False
        )
        slp_pt.attrs["frequency"] = "daily"

    # Convert to hPa
    slp_pt = slp_pt / 100.0
    slp_pt.attrs["units"] = "hPa"

    # Add dummy time axis
    slp_pt = add_dummy_time_to_wl(slp_pt)

    return slp_pt

# %% [markdown]
# Access the three variables (surface pressure, air temperature, and mixing ratio) we need to get sea level pressure. Results are clipped to the two points of interest. This cell will take several minutes to run.

# %%
cd = ck.ClimateData(verbosity=1)

# Surface pressure
psfc = (
    cd.catalog("cadcat")
    .activity_id("WRF")
    .institution_id("UCLA")
    .table_id(frequency)
    .grid_label("d03")
    .variable("psfc")
    .processes(
        {
            "clip": {"points":[gradient_point_1, gradient_point_2],
                     "separated": True},
            "warming_level": {
                "warming_levels": [baseline_gwl, future_gwl],
            },
        }
    )
    .get()
)

# Air temperature
t2 = (
    cd.catalog("cadcat")
    .activity_id("WRF")
    .institution_id("UCLA")
    .table_id(frequency)
    .grid_label("d03")
    .variable("t2")
    .processes(
        {
            "clip": {"points":[gradient_point_1, gradient_point_2],
                     "separated": True},
            "warming_level": {
                "warming_levels": [baseline_gwl, future_gwl],
            },
        }
    )
    .get()
)

# Mixing ratio
q2 = (
    cd.catalog("cadcat")
    .activity_id("WRF")
    .institution_id("UCLA")
    .table_id(frequency)
    .grid_label("d03")
    .variable("q2")
    .processes(
        {
            "clip": {"points":[gradient_point_1, gradient_point_2],
                     "separated": True},
            "warming_level": {
                "warming_levels": [baseline_gwl, future_gwl],
            },
        }
    )
    .get()
)
# Out:
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Initializing ClimateData interface
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Initializing DatasetFactory
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - INFO - DatasetFactory initialized with 3 validators and 11 processors
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - ClimateData initialization successful
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - ✅ Ready to query!
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Setting catalog to: cadcat
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Catalog set to: cadcat
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Setting activity_id to: WRF
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Activity ID set to: WRF
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Setting institution_id to: UCLA
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Institution ID set to: UCLA
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Setting table_id to: 1hr
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Table ID set to: 1hr
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Setting grid_label to: d03
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Grid label set to: d03
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Setting variable to: psfc
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Variable set to: psfc
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Setting processes to: {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}}
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Processes set: 2 operations configured
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Starting data retrieval with query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}}}
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Validating required parameters
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Creating dataset using factory
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Creating dataset from query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}}}
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - INFO - Determined catalog key: cadcat
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Creating validator for catalog: cadcat
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.cadcat_param_validator - DEBUG - DataValidator initialized for catalog with keys: ['LOCA2.UCSD.ACCESS-CM2.historical.day.d03', 'LOCA2.UCSD.ACCESS-CM2.historical.mon.d03', 'LOCA2.UCSD.ACCESS-CM2.historical.yrmax.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp245.day.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp245.mon.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp245.yrmax.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp370.day.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp370.mon.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp370.yrmax.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp585.day.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp585.mon.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp585.yrmax.d03', 'LOCA2.UCSD.CESM2-LENS.historical.day.d03', 'LOCA2.UCSD.CESM2-LENS.historical.mon.d03', 'LOCA2.UCSD.CESM2-LENS.historical.yrmax.d03', 'LOCA2.UCSD.CESM2-LENS.ssp370.day.d03', 'LOCA2.UCSD.CESM2-LENS.ssp370.mon.d03', 'LOCA2.UCSD.CESM2-LENS.ssp370.yrmax.d03', 'LOCA2.UCSD.CNRM-ESM2-1.historical.day.d03', 'LOCA2.UCSD.CNRM-ESM2-1.historical.mon.d03', 'LOCA2.UCSD.CNRM-ESM2-1.historical.yrmax.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp245.day.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp245.mon.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp245.yrmax.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp370.day.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp370.mon.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp370.yrmax.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp585.day.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp585.mon.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp585.yrmax.d03', 'LOCA2.UCSD.EC-Earth3.historical.day.d03', 'LOCA2.UCSD.EC-Earth3.historical.mon.d03', 'LOCA2.UCSD.EC-Earth3.historical.yrmax.d03', 'LOCA2.UCSD.EC-Earth3.ssp245.day.d03', 'LOCA2.UCSD.EC-Earth3.ssp245.mon.d03', 'LOCA2.UCSD.EC-Earth3.ssp245.yrmax.d03', 'LOCA2.UCSD.EC-Earth3.ssp370.day.d03', 'LOCA2.UCSD.EC-Earth3.ssp370.mon.d03', 'LOCA2.UCSD.EC-Earth3.ssp370.yrmax.d03', 'LOCA2.UCSD.EC-Earth3.ssp585.day.d03', 'LOCA2.UCSD.EC-Earth3.ssp585.mon.d03', 'LOCA2.UCSD.EC-Earth3.ssp585.yrmax.d03', 'LOCA2.UCSD.EC-Earth3-Veg.historical.day.d03', 'LOCA2.UCSD.EC-Earth3-Veg.historical.mon.d03', 'LOCA2.UCSD.EC-Earth3-Veg.historical.yrmax.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp245.day.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp245.mon.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp245.yrmax.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp370.day.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp370.mon.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp370.yrmax.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp585.day.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp585.mon.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp585.yrmax.d03', 'LOCA2.UCSD.FGOALS-g3.historical.day.d03', 'LOCA2.UCSD.FGOALS-g3.historical.mon.d03', 'LOCA2.UCSD.FGOALS-g3.historical.yrmax.d03', 'LOCA2.UCSD.FGOALS-g3.ssp245.day.d03', 'LOCA2.UCSD.FGOALS-g3.ssp245.mon.d03', 'LOCA2.UCSD.FGOALS-g3.ssp245.yrmax.d03', 'LOCA2.UCSD.FGOALS-g3.ssp370.day.d03', 'LOCA2.UCSD.FGOALS-g3.ssp370.mon.d03', 'LOCA2.UCSD.FGOALS-g3.ssp370.yrmax.d03', 'LOCA2.UCSD.FGOALS-g3.ssp585.day.d03', 'LOCA2.UCSD.FGOALS-g3.ssp585.mon.d03', 'LOCA2.UCSD.FGOALS-g3.ssp585.yrmax.d03', 'LOCA2.UCSD.GFDL-ESM4.historical.day.d03', 'LOCA2.UCSD.GFDL-ESM4.historical.mon.d03', 'LOCA2.UCSD.GFDL-ESM4.historical.yrmax.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp245.day.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp245.mon.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp245.yrmax.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp370.day.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp370.mon.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp370.yrmax.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp585.day.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp585.mon.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp585.yrmax.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.historical.day.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.historical.mon.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.historical.yrmax.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp245.day.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp245.mon.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp245.yrmax.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp585.day.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp585.mon.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp585.yrmax.d03', 'LOCA2.UCSD.INM-CM5-0.historical.day.d03', 'LOCA2.UCSD.INM-CM5-0.historical.mon.d03', 'LOCA2.UCSD.INM-CM5-0.historical.yrmax.d03', 'LOCA2.UCSD.INM-CM5-0.ssp245.day.d03 ...
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Configuring dataset with data catalog
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Determining processing steps for query
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.cadcat_param_validator - DEBUG - DataValidator initialized for catalog with keys: ['LOCA2.UCSD.ACCESS-CM2.historical.day.d03', 'LOCA2.UCSD.ACCESS-CM2.historical.mon.d03', 'LOCA2.UCSD.ACCESS-CM2.historical.yrmax.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp245.day.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp245.mon.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp245.yrmax.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp370.day.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp370.mon.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp370.yrmax.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp585.day.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp585.mon.d03', 'LOCA2.UCSD.ACCESS-CM2.ssp585.yrmax.d03', 'LOCA2.UCSD.CESM2-LENS.historical.day.d03', 'LOCA2.UCSD.CESM2-LENS.historical.mon.d03', 'LOCA2.UCSD.CESM2-LENS.historical.yrmax.d03', 'LOCA2.UCSD.CESM2-LENS.ssp370.day.d03', 'LOCA2.UCSD.CESM2-LENS.ssp370.mon.d03', 'LOCA2.UCSD.CESM2-LENS.ssp370.yrmax.d03', 'LOCA2.UCSD.CNRM-ESM2-1.historical.day.d03', 'LOCA2.UCSD.CNRM-ESM2-1.historical.mon.d03', 'LOCA2.UCSD.CNRM-ESM2-1.historical.yrmax.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp245.day.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp245.mon.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp245.yrmax.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp370.day.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp370.mon.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp370.yrmax.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp585.day.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp585.mon.d03', 'LOCA2.UCSD.CNRM-ESM2-1.ssp585.yrmax.d03', 'LOCA2.UCSD.EC-Earth3.historical.day.d03', 'LOCA2.UCSD.EC-Earth3.historical.mon.d03', 'LOCA2.UCSD.EC-Earth3.historical.yrmax.d03', 'LOCA2.UCSD.EC-Earth3.ssp245.day.d03', 'LOCA2.UCSD.EC-Earth3.ssp245.mon.d03', 'LOCA2.UCSD.EC-Earth3.ssp245.yrmax.d03', 'LOCA2.UCSD.EC-Earth3.ssp370.day.d03', 'LOCA2.UCSD.EC-Earth3.ssp370.mon.d03', 'LOCA2.UCSD.EC-Earth3.ssp370.yrmax.d03', 'LOCA2.UCSD.EC-Earth3.ssp585.day.d03', 'LOCA2.UCSD.EC-Earth3.ssp585.mon.d03', 'LOCA2.UCSD.EC-Earth3.ssp585.yrmax.d03', 'LOCA2.UCSD.EC-Earth3-Veg.historical.day.d03', 'LOCA2.UCSD.EC-Earth3-Veg.historical.mon.d03', 'LOCA2.UCSD.EC-Earth3-Veg.historical.yrmax.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp245.day.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp245.mon.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp245.yrmax.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp370.day.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp370.mon.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp370.yrmax.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp585.day.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp585.mon.d03', 'LOCA2.UCSD.EC-Earth3-Veg.ssp585.yrmax.d03', 'LOCA2.UCSD.FGOALS-g3.historical.day.d03', 'LOCA2.UCSD.FGOALS-g3.historical.mon.d03', 'LOCA2.UCSD.FGOALS-g3.historical.yrmax.d03', 'LOCA2.UCSD.FGOALS-g3.ssp245.day.d03', 'LOCA2.UCSD.FGOALS-g3.ssp245.mon.d03', 'LOCA2.UCSD.FGOALS-g3.ssp245.yrmax.d03', 'LOCA2.UCSD.FGOALS-g3.ssp370.day.d03', 'LOCA2.UCSD.FGOALS-g3.ssp370.mon.d03', 'LOCA2.UCSD.FGOALS-g3.ssp370.yrmax.d03', 'LOCA2.UCSD.FGOALS-g3.ssp585.day.d03', 'LOCA2.UCSD.FGOALS-g3.ssp585.mon.d03', 'LOCA2.UCSD.FGOALS-g3.ssp585.yrmax.d03', 'LOCA2.UCSD.GFDL-ESM4.historical.day.d03', 'LOCA2.UCSD.GFDL-ESM4.historical.mon.d03', 'LOCA2.UCSD.GFDL-ESM4.historical.yrmax.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp245.day.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp245.mon.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp245.yrmax.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp370.day.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp370.mon.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp370.yrmax.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp585.day.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp585.mon.d03', 'LOCA2.UCSD.GFDL-ESM4.ssp585.yrmax.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.historical.day.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.historical.mon.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.historical.yrmax.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp245.day.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp245.mon.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp245.yrmax.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp585.day.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp585.mon.d03', 'LOCA2.UCSD.HadGEM3-GC31-LL.ssp585.yrmax.d03', 'LOCA2.UCSD.INM-CM5-0.historical.day.d03', 'LOCA2.UCSD.INM-CM5-0.historical.mon.d03', 'LOCA2.UCSD.INM-CM5-0.historical.yrmax.d03', 'LOCA2.UCSD.INM-CM5-0.ssp245.day.d03 ...
# 2026-03-03 18:33:57 - climakitae.new_core.processors.clip - DEBUG - Clip processor initialized value=[(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)] multi_mode=False is_multi_point=True is_single_point=False separated=False
# 2026-03-03 18:33:57 - climakitae.new_core.processors.warming_level - DEBUG - WarmingLevel initialized with warming_levels=[0.8, 1.5] window=15
# 2026-03-03 18:33:57 - climakitae.new_core.processors.filter_unadjusted_models - DEBUG - FilterUnAdjustedModels initialized with value=yes
# 2026-03-03 18:33:57 - climakitae.new_core.processors.drop_leap_days - DEBUG - DropLeapDays initialized with value=yes
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - INFO - Adding 6 processing steps to dataset
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Adding processing step: <climakitae.new_core.processors.filter_unadjusted_models.FilterUnAdjustedModels object at 0x7fca383f2840>
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Adding processing step: <climakitae.new_core.processors.drop_leap_days.DropLeapDays object at 0x7fca764a3470>
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Adding processing step: <climakitae.new_core.processors.warming_level.WarmingLevel object at 0x7fca35f2ce30>
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Adding processing step: <climakitae.new_core.processors.concatenate.Concat object at 0x7fca34adbec0>
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Adding processing step: <climakitae.new_core.processors.clip.Clip object at 0x7fca5ff65dc0>
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - DEBUG - Adding processing step: <climakitae.new_core.processors.update_attributes.UpdateAttributes object at 0x7fca383f35f0>
# 2026-03-03 18:33:57 - climakitae.new_core.dataset_factory - INFO - Dataset created successfully
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - INFO - Dataset created successfully
# 2026-03-03 18:33:57 - climakitae.new_core.user_interface - DEBUG - Executing query
# 2026-03-03 18:33:57 - climakitae.new_core.dataset - INFO - Executing dataset processing pipeline
# 2026-03-03 18:33:57 - climakitae.new_core.dataset - DEBUG - Pipeline parameters: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}, '_catalog_key': 'cadcat', 'new_attrs': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}}
# 2026-03-03 18:33:57 - climakitae.new_core.dataset - DEBUG - Validating parameters
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.cadcat_param_validator - DEBUG - Validating query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}, '_catalog_key': 'cadcat', 'new_attrs': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.cadcat_param_validator - DEBUG - Checking WRF/localize constraints for query processes: {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.cadcat_param_validator - DEBUG - Checking for required keys in query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}, '_catalog_key': 'cadcat', 'new_attrs': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.abc_param_validation - INFO - Found 17 datasets matching your query.
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.abc_param_validation - INFO - Checking processes ...
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.clip_param_validator - DEBUG - validate_clip_param called with value: {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.clip_param_validator - DEBUG - _validate_dict_param called with: {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.clip_param_validator - DEBUG - Points dict parameter validated successfully
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.warming_param_validator - DEBUG - validate_warming_level_param called with value={'warming_levels': [0.8, 1.5]} kwargs={'query': {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}, '_catalog_key': 'cadcat', 'new_attrs': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}}}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.warming_param_validator - DEBUG - _check_input_types called with value: {'warming_levels': [0.8, 1.5]}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.warming_param_validator - DEBUG - _check_catalog called with query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}, '_catalog_key': 'cadcat', 'new_attrs': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.warming_param_validator - DEBUG - _check_query called with query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}, '_catalog_key': 'cadcat', 'new_attrs': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}}
# 2026-03-03 18:33:57 - climakitae.new_core.param_validation.warming_param_validator - DEBUG - _check_wl_values called with value: {'warming_levels': [0.8, 1.5]}, query: {'catalog': 'cadcat', 'installation': UNSET, 'activity_id': 'WRF', 'institution_id': 'UCLA', 'source_id': UNSET, 'experiment_id': UNSET, 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc', 'station_id': UNSET, 'network_id': UNSET, 'processes': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}, '_catalog_key': 'cadcat', 'new_attrs': {'clip': {'points': [(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)], 'separated': True}, 'warming_level': {'warming_levels': [0.8, 1.5]}, 'update_attributes': UNSET, 'filter_unadjusted_models': 'yes', 'drop_leap_days': 'yes', 'concat': 'time'}}
# 2026-03-03 18:33:58 - climakitae.new_core.param_validation.warming_param_validator - DEBUG - Available trajectories min=-0.39 max=5.73
# 2026-03-03 18:33:58 - climakitae.new_core.param_validation.concat_param_validator - DEBUG - validate_concat_param called with value: time
# 2026-03-03 18:33:58 - climakitae.new_core.param_validation.cadcat_param_validator - INFO - Query validation result: True
# 2026-03-03 18:33:58 - climakitae.new_core.dataset - INFO - Parameter validation successful
# 2026-03-03 18:33:58 - climakitae.new_core.dataset - DEBUG - Retrieving data from data accessor with catalog_key=cadcat
# 2026-03-03 18:33:58 - climakitae.new_core.data_access.data_access - INFO - Querying cadcat catalog
# 2026-03-03 18:33:58 - climakitae.new_core.data_access.data_access - DEBUG - Query parameters: {'activity_id': 'WRF', 'institution_id': 'UCLA', 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc'}
# 2026-03-03 18:33:58 - climakitae.new_core.data_access.data_access - DEBUG - Querying cadcat catalog with query: {'activity_id': 'WRF', 'institution_id': 'UCLA', 'table_id': '1hr', 'grid_label': 'd03', 'variable_id': 'psfc'}
# 2026-03-03 18:33:58 - climakitae.new_core.data_access.data_access - DEBUG - Executing catalog search
# 2026-03-03 18:34:02 - climakitae.new_core.data_access.data_access - INFO - Retrieved 17 dataset(s) from catalog
# 2026-03-03 18:34:02 - climakitae.new_core.data_access.data_access - DEBUG - Retrieved datasets: ['WRF.UCLA.CESM2.historical.1hr.d03', 'WRF.UCLA.FGOALS-g3.ssp370.1hr.d03', 'WRF.UCLA.EC-Earth3.historical.1hr.d03', 'WRF.UCLA.EC-Earth3-Veg.ssp370.1hr.d03', 'WRF.UCLA.EC-Earth3-Veg.historical.1hr.d03', 'WRF.UCLA.CNRM-ESM2-1.historical.1hr.d03', 'WRF.UCLA.EC-Earth3.ssp370.1hr.d03', 'WRF.UCLA.FGOALS-g3.historical.1hr.d03', 'WRF.UCLA.ERA5.reanalysis.1hr.d03', 'WRF.UCLA.MIROC6.ssp370.1hr.d03', 'WRF.UCLA.CNRM-ESM2-1.ssp370.1hr.d03', 'WRF.UCLA.TaiESM1.ssp370.1hr.d03', 'WRF.UCLA.MIROC6.historical.1hr.d03', 'WRF.UCLA.CESM2.ssp370.1hr.d03', 'WRF.UCLA.TaiESM1.historical.1hr.d03', 'WRF.UCLA.MPI-ESM1-2-HR.historical.1hr.d03', 'WRF.UCLA.MPI-ESM1-2-HR.ssp370.1hr.d03']
# 2026-03-03 18:34:02 - climakitae.new_core.dataset - INFO - Data retrieved successfully
# 2026-03-03 18:34:02 - climakitae.new_core.dataset - INFO - Executing 6 processing steps
# 2026-03-03 18:34:02 - climakitae.new_core.dataset - DEBUG - Executing processing step 1/6: filter_unadjusted_models
# 2026-03-03 18:34:02 - climakitae.new_core.dataset - DEBUG - BEFORE:
# {'WRF.UCLA.CESM2.historical.1hr.d03': <xarray.Dataset> Size: 142GB
# Dimensions:            (member_id: 1, time: 297840, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r11i1p1f1'
#   * time               (time) datetime64[ns] 2MB 1980-09-01 ... 2014-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 142GB dask.array<chunksize=(1, 9143, 87, 42), meta=np.ndarray>
# Attributes: (12/107)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/cesm2/historical/1...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.CESM2.historical.1hr.d03, 'WRF.UCLA.FGOALS-g3.ssp370.1hr.d03': <xarray.Dataset> Size: 360GB
# Dimensions:            (member_id: 1, time: 753360, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 6MB 2014-09-01 ... 2100-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 360GB dask.array<chunksize=(1, 14541, 69, 33), meta=np.ndarray>
# Attributes: (12/107)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/fgoals-g3/ssp370/1...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.FGOALS-g3.ssp370.1hr.d03, 'WRF.UCLA.EC-Earth3.historical.1hr.d03': <xarray.Dataset> Size: 143GB
# Dimensions:            (member_id: 1, time: 298032, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 2MB 1980-09-01 ... 2014-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 143GB dask.array<chunksize=(1, 9146, 87, 42), meta=np.ndarray>
# Attributes: (12/110)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/ec-earth3/historic...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.EC-Earth3.historical.1hr.d03, 'WRF.UCLA.EC-Earth3-Veg.ssp370.1hr.d03': <xarray.Dataset> Size: 361GB
# Dimensions:            (member_id: 1, time: 753864, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 6MB 2014-09-01 ... 2100-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 361GB dask.array<chunksize=(1, 14546, 69, 33), meta=np.ndarray>
# Attributes: (12/110)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/ec-earth3-veg/ssp3...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.EC-Earth3-Veg.ssp370.1hr.d03, 'WRF.UCLA.EC-Earth3-Veg.historical.1hr.d03': <xarray.Dataset> Size: 143GB
# Dimensions:            (member_id: 1, time: 298032, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 2MB 1980-09-01 ... 2014-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 143GB dask.array<chunksize=(1, 9146, 87, 42), meta=np.ndarray>
# Attributes: (12/110)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/ec-earth3-veg/hist...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.EC-Earth3-Veg.historical.1hr.d03, 'WRF.UCLA.CNRM-ESM2-1.historical.1hr.d03': <xarray.Dataset> Size: 142GB
# Dimensions:            (member_id: 1, time: 297840, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f2'
#   * time               (time) datetime64[ns] 2MB 1980-09-01 ... 2014-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 142GB dask.array<chunksize=(1, 9143, 87, 42), meta=np.ndarray>
# Attributes: (12/107)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/cnrm-esm2-1/histor...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.CNRM-ESM2-1.historical.1hr.d03, 'WRF.UCLA.EC-Earth3.ssp370.1hr.d03': <xarray.Dataset> Size: 361GB
# Dimensions:            (member_id: 1, time: 753864, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 6MB 2014-09-01 ... 2100-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 361GB dask.array<chunksize=(1, 14546, 69, 33), meta=np.ndarray>
# Attributes: (12/110)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/ec-earth3/ssp370/1...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.EC-Earth3.ssp370.1hr.d03, 'WRF.UCLA.FGOALS-g3.historical.1hr.d03': <xarray.Dataset> Size: 142GB
# Dimensions:            (member_id: 1, time: 297840, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 2MB 1980-09-01 ... 2014-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 142GB dask.array<chunksize=(1, 9143, 87, 42), meta=np.ndarray>
# Attributes: (12/107)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/fgoals-g3/historic...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.FGOALS-g3.historical.1hr.d03, 'WRF.UCLA.ERA5.reanalysis.1hr.d03': <xarray.Dataset> Size: 168GB
# Dimensions:            (member_id: 1, time: 350640, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) float64 8B nan
#   * time               (time) datetime64[ns] 3MB 1980-09-01 ... 2020-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(72, 35), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(72, 35), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(72, 35), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(72, 35), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 168GB dask.array<chunksize=(1, 13217, 72, 35), meta=np.ndarray>
# Attributes: (12/109)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/era5/reanalysis/1h...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.ERA5.reanalysis.1hr.d03, 'WRF.UCLA.MIROC6.ssp370.1hr.d03': <xarray.Dataset> Size: 361GB
# Dimensions:            (member_id: 1, time: 753864, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 6MB 2014-09-01 ... 2100-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 361GB dask.array<chunksize=(1, 14546, 69, 33), meta=np.ndarray>
# Attributes: (12/110)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/miroc6/ssp370/1hr/...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.MIROC6.ssp370.1hr.d03, 'WRF.UCLA.CNRM-ESM2-1.ssp370.1hr.d03': <xarray.Dataset> Size: 360GB
# Dimensions:            (member_id: 1, time: 753360, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f2'
#   * time               (time) datetime64[ns] 6MB 2014-09-01 ... 2100-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 360GB dask.array<chunksize=(1, 14541, 69, 33), meta=np.ndarray>
# Attributes: (12/107)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/cnrm-esm2-1/ssp370...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.CNRM-ESM2-1.ssp370.1hr.d03, 'WRF.UCLA.TaiESM1.ssp370.1hr.d03': <xarray.Dataset> Size: 360GB
# Dimensions:            (member_id: 1, time: 753360, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 6MB 2014-09-01 ... 2100-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 360GB dask.array<chunksize=(1, 14546, 69, 33), meta=np.ndarray>
# Attributes: (12/110)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/taiesm1/ssp370/1hr...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.TaiESM1.ssp370.1hr.d03, 'WRF.UCLA.MIROC6.historical.1hr.d03': <xarray.Dataset> Size: 143GB
# Dimensions:            (member_id: 1, time: 298032, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 2MB 1980-09-01 ... 2014-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 143GB dask.array<chunksize=(1, 9146, 87, 42), meta=np.ndarray>
# Attributes: (12/110)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/miroc6/historical/...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.MIROC6.historical.1hr.d03, 'WRF.UCLA.CESM2.ssp370.1hr.d03': <xarray.Dataset> Size: 360GB
# Dimensions:            (member_id: 1, time: 753360, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r11i1p1f1'
#   * time               (time) datetime64[ns] 6MB 2014-09-01 ... 2100-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(69, 33), meta=np.ndarray>
# Data variables:
#     psfc               (member_id, time, y, x) float32 360GB dask.array<chunksize=(1, 14541, 69, 33), meta=np.ndarray>
# Attributes: (12/107)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:variable_id:     psfc
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/cesm2/ssp370/1hr/p...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.CESM2.ssp370.1hr.d03, 'WRF.UCLA.TaiESM1.historical.1hr.d03': <xarray.Dataset> Size: 142GB
# Dimensions:            (member_id: 1, time: 297840, y: 492, x: 243)
# Coordinates:
#   * member_id          (member_id) object 8B 'r1i1p1f1'
#   * time               (time) datetime64[ns] 2MB 1980-09-01 ... 2014-08-31T23...
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B ...
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
# ...
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/miroc6/ssp370/1hr/...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.MIROC6.ssp370.1hr.d03
#     historical_prepended:             True, 'WRF.UCLA.TaiESM1.ssp370.1hr.d03.r1i1p1f1': <xarray.Dataset> Size: 251GB
# Dimensions:            (warming_level: 2, time_delta: 262800, y: 492, x: 243)
# Coordinates:
#   * warming_level      (warming_level) float64 16B 0.8 1.5
#   * time_delta         (time_delta) int64 2MB -131400 -131399 ... 131398 131399
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B 1
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     simulation         <U40 160B 'WRF.UCLA.TaiESM1.ssp370.1hr.d03.r1i1p1f1'
# Data variables:
#     psfc               (warming_level, time_delta, y, x) float32 251GB dask.array<chunksize=(1, 2858, 69, 33), meta=np.ndarray>
# Attributes: (12/111)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/taiesm1/ssp370/1hr...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.TaiESM1.ssp370.1hr.d03
#     historical_prepended:             True, 'WRF.UCLA.MPI-ESM1-2-HR.ssp370.1hr.d03.r3i1p1f1': <xarray.Dataset> Size: 251GB
# Dimensions:            (warming_level: 2, time_delta: 262800, y: 492, x: 243)
# Coordinates:
#   * warming_level      (warming_level) float64 16B 0.8 1.5
#   * time_delta         (time_delta) int64 2MB -131400 -131399 ... 131398 131399
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B 1
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     simulation         <U46 184B 'WRF.UCLA.MPI-ESM1-2-HR.ssp370.1hr.d03.r3i1p...
# Data variables:
#     psfc               (warming_level, time_delta, y, x) float32 251GB dask.array<chunksize=(1, 5744, 69, 33), meta=np.ndarray>
# Attributes: (12/111)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:grid_label:      d03
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/mpi-esm1-2-hr/ssp3...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.MPI-ESM1-2-HR.ssp370.1hr.d03
#     historical_prepended:             True}
# 2026-03-03 18:34:23 - climakitae.new_core.processors.concatenate - INFO - Concatenated datasets along 'sim' dimension.
# 2026-03-03 18:34:23 - climakitae.new_core.processors.concatenate - DEBUG - Dropped 'simulation' coordinate from concatenated dataset.
# 2026-03-03 18:34:23 - climakitae.new_core.processors.concatenate - DEBUG - Assigned centered_years for sim WRF_UCLA_EC-Earth3-Veg_ssp370_1hr_d03_r1i1p1f1 (key=WRF.UCLA.EC-Earth3-Veg.ssp370.1hr.d03.r1i1p1f1): [2005]
# 2026-03-03 18:34:23 - climakitae.new_core.processors.concatenate - DEBUG - Assigned centered_years for sim WRF_UCLA_EC-Earth3_ssp370_1hr_d03_r1i1p1f1 (key=WRF.UCLA.EC-Earth3.ssp370.1hr.d03.r1i1p1f1): [2003, 2018]
# 2026-03-03 18:34:23 - climakitae.new_core.processors.concatenate - DEBUG - Assigned centered_years for sim WRF_UCLA_MIROC6_ssp370_1hr_d03_r1i1p1f1 (key=WRF.UCLA.MIROC6.ssp370.1hr.d03.r1i1p1f1): [2012, 2040]
# 2026-03-03 18:34:23 - climakitae.new_core.processors.concatenate - DEBUG - Assigned centered_years for sim WRF_UCLA_TaiESM1_ssp370_1hr_d03_r1i1p1f1 (key=WRF.UCLA.TaiESM1.ssp370.1hr.d03.r1i1p1f1): [2011, 2031]
# 2026-03-03 18:34:23 - climakitae.new_core.processors.concatenate - DEBUG - Assigned centered_years for sim WRF_UCLA_MPI-ESM1-2-HR_ssp370_1hr_d03_r3i1p1f1 (key=WRF.UCLA.MPI-ESM1-2-HR.ssp370.1hr.d03.r3i1p1f1): [1996, 2028]
# 2026-03-03 18:34:23 - climakitae.new_core.processors.concatenate - DEBUG - Successfully created 2D centered_year coordinate with shape (5, 2)
# 2026-03-03 18:34:23 - climakitae.new_core.dataset - DEBUG - AFTER:
# <xarray.Dataset> Size: 1TB
# Dimensions:            (sim: 5, warming_level: 2, time_delta: 262800, y: 492,
#                         x: 243)
# Coordinates:
#   * sim                (sim) object 40B 'WRF_UCLA_EC-Earth3-Veg_ssp370_1hr_d0...
#   * warming_level      (warming_level) float64 16B 0.8 1.5
#   * time_delta         (time_delta) int64 2MB -131400 -131399 ... 131398 131399
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B 1
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     centered_year      (sim, warming_level) float64 80B 2.005e+03 ... 2.028e+03
# Data variables:
#     psfc               (sim, warming_level, time_delta, y, x) float32 1TB dask.array<chunksize=(1, 1, 1408, 69, 33), meta=np.ndarray>
# Attributes: (12/112)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/ec-earth3-veg/ssp3...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.EC-Earth3-Veg.ssp370.1hr.d03
#     historical_prepended:             True
#     resolution:                       3 km
# 2026-03-03 18:34:23 - climakitae.new_core.dataset - DEBUG - Processing step 4 completed successfully
# 2026-03-03 18:34:23 - climakitae.new_core.dataset - DEBUG - Executing processing step 5/6: clip
# 2026-03-03 18:34:23 - climakitae.new_core.dataset - DEBUG - Step requires data catalog access
# 2026-03-03 18:34:23 - climakitae.new_core.dataset - DEBUG - BEFORE:
# <xarray.Dataset> Size: 1TB
# Dimensions:            (sim: 5, warming_level: 2, time_delta: 262800, y: 492,
#                         x: 243)
# Coordinates:
#   * sim                (sim) object 40B 'WRF_UCLA_EC-Earth3-Veg_ssp370_1hr_d0...
#   * warming_level      (warming_level) float64 16B 0.8 1.5
#   * time_delta         (time_delta) int64 2MB -131400 -131399 ... 131398 131399
#   * y                  (y) float64 4kB 4.549e+05 4.579e+05 ... 1.928e+06
#   * x                  (x) float64 2kB -4.335e+06 -4.332e+06 ... -3.609e+06
#     Lambert_Conformal  int32 4B 1
#     lakemask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     landmask           (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lat                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     lon                (y, x) float32 478kB dask.array<chunksize=(87, 42), meta=np.ndarray>
#     centered_year      (sim, warming_level) float64 80B 2.005e+03 ... 2.028e+03
# Data variables:
#     psfc               (sim, warming_level, time_delta, y, x) float32 1TB dask.array<chunksize=(1, 1, 1408, 69, 33), meta=np.ndarray>
# Attributes: (12/112)
#     AERCU_FCT:                        1.0
#     AERCU_OPT:                        0
#     AUTO_LEVELS_OPT:                  2
#     BL_PBL_PHYSICS:                   1
#     BOTTOM-TOP_GRID_DIMENSION:        40
#     BOTTOM-TOP_PATCH_END_STAG:        40
#     ...                               ...
#     intake_esm_attrs:path:            s3://cadcat/wrf/ucla/ec-earth3-veg/ssp3...
#     intake_esm_attrs:catalog:         cadcat
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           WRF.UCLA.EC-Earth3-Veg.ssp370.1hr.d03
#     historical_prepended:             True
#     resolution:                       3 km
# 2026-03-03 18:34:23 - climakitae.new_core.processors.clip - DEBUG - Clip.execute called with value=[(34.031899244954694, -118.47507877286985), (34.31392420709518, -116.16003299789273)] result_type=Dataset
# 2026-03-03 18:34:23 - climakitae.new_core.processors.clip - INFO - Applying point mask to data with 2 points (extract_points=True)
# 2026-03-03 18:34:24 - climakitae.new_core.processors.clip - DEBUG - Found 2 unique grid cells from 2 input points
# 2026-03-03 18:35:25 - climakitae.new_core.processors.clip - DEBUG - 0 points have valid data, 2 need 3x3 averaging
# 2026-03-03 18:35:25 - climakitae.new_core.processors.clip - INFO - Computing 3x3 neighborhood averages for 2 points
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 20
#       1 cd = ck.ClimateData(verbosity=1)
#       3 # Surface pressure
#       4 psfc = (
#       5     cd.catalog("cadcat")
#       6     .activity_id("WRF")
#       7     .institution_id("UCLA")
#       8     .table_id(frequency)
#       9     .grid_label("d03")
#      10     .variable("psfc")
#      11     .processes(
#      12         {
#      13             "clip": {"points":[gradient_point_1, gradient_point_2],
#      14                      "separated": True},
#      15             "warming_level": {
#      16                 "warming_levels": [baseline_gwl, future_gwl],
#      17             },
#      18         }
#      19     )
# ---> 20     .get()
#      21 )
#      23 # Air temperature
#      24 t2 = (
#      25     cd.catalog("cadcat")
#      26     .activity_id("WRF")
#    (...)     40     .get()
#      41 )
#
# File ~/.local/lib/python3.12/site-packages/climakitae/new_core/user_interface.py:872, in ClimateData.get(self)
#     869 try:
#     870     # Execute the query with the snapshot
#     871     logger.debug("Executing query")
# --> 872     data = dataset.execute(query_snapshot)
#     873     # check if empty dataset
#     874     # Check if data is empty/null
#     875     if (
#     876         data is None
#     877         or (hasattr(data, "nbytes") and data.nbytes == 0)
#     878         or (isinstance(data, dict) and not data)
#     879     ):
#
# File ~/.local/lib/python3.12/site-packages/climakitae/new_core/dataset.py:246, in Dataset.execute(self, parameters)
#     243 # Execute the current step
#     244 # context is updated in place by the step
#     245 logger.debug("BEFORE:\n%s", current_result)
# --> 246 current_result = step.execute(current_result, context)
#     247 logger.debug("AFTER:\n%s", current_result)
#     249 if current_result is None:
#
# File ~/.local/lib/python3.12/site-packages/climakitae/new_core/processors/clip.py:417, in Clip.execute(self, result, context)
#     415     ret = self._clip_data_to_point(result, self.lat, self.lon)
#     416 elif self.is_multi_point:
# --> 417     ret = self._clip_data_to_points_as_mask(
#     418         result, self.point_list, self.extract_points
#     419     )
#     420 elif self.separated:
#     421     ret = self._clip_data_separated(result, self.value)
#
# File ~/.local/lib/python3.12/site-packages/climakitae/new_core/processors/clip.py:1241, in Clip._clip_data_to_points_as_mask(dataset, point_list, extract_points)
#    1238 if isinstance(masked_data, xr.Dataset):
#    1239     for var in masked_data.data_vars:
#    1240         # Create indexer for this specific cell
# -> 1241         masked_data[var].loc[
#    1242             {lat_dim: lat_coords[lat_idx], lon_dim: lon_coords[lon_idx]}
#    1243         ] = neighborhood_mean[var]
#    1244 else:
#    1245     masked_data.loc[
#    1246         {lat_dim: lat_coords[lat_idx], lon_dim: lon_coords[lon_idx]}
#    1247     ] = neighborhood_mean
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/core/dataarray.py:249, in _LocIndexer.__setitem__(self, key, value)
#     246     key = dict(zip(self.data_array.dims, labels, strict=True))
#     248 dim_indexers = map_index_queries(self.data_array, key).dim_indexers
# --> 249 self.data_array[dim_indexers] = value
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/core/dataarray.py:906, in DataArray.__setitem__(self, key, value)
#     901 # DataArray key -> Variable key
#     902 key = {
#     903     k: v.variable if isinstance(v, DataArray) else v
#     904     for k, v in self._item_key_to_dict(key).items()
#     905 }
# --> 906 self.variable[key] = value
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/core/variable.py:903, in Variable.__setitem__(self, key, value)
#     900     value = duck_array_ops.moveaxis(value, new_order, range(len(new_order)))
#     902 indexable = as_indexable(self._data)
# --> 903 indexing.set_with_indexer(indexable, index_tuple, value)
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/core/indexing.py:1169, in set_with_indexer(indexable, indexer, value)
#    1167     indexable.oindex[indexer] = value
#    1168 else:
# -> 1169     indexable[indexer] = value
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/xarray/core/indexing.py:1865, in DaskIndexingAdapter.__setitem__(self, indexer, value)
#    1863 def __setitem__(self, indexer: ExplicitIndexer, value: Any) -> None:
#    1864     self._check_and_raise_if_non_basic_indexer(indexer)
# -> 1865     self.array[indexer.tuple] = value
#
# File ~/.local/lib/python3.12/site-packages/dask/array/core.py:1968, in Array.__setitem__(self, key, value)
#    1966 token = tokenize(self, key, value)
#    1967 out = f"setitem-{token}"
# -> 1968 dsk = setitem_array(out, self, key, value)
#    1970 meta = meta_from_array(self._meta)
#    1971 if np.isscalar(meta):
#
# File ~/.local/lib/python3.12/site-packages/dask/array/slicing.py:2017, in setitem_array(out_name, array, indices, value)
#    2012 v_key = next(flatten(v.__dask_keys__()))
#    2014 # Insert into the output dask dictionary the dask of the part
#    2015 # of assignment value for this block (not minding when we
#    2016 # overwrite any existing keys as the values will be the same).
# -> 2017 dsk = merge(dict(v.dask), dsk)
#    2019 # Define the assignment function for this block.
#    2020 dsk[out_key] = (setitem, in_key, v_key, block_indices)
#
# File ~/.local/lib/python3.12/site-packages/dask/highlevelgraph.py:540, in HighLevelGraph.__getitem__(self, key)
#     538     pass
#     539 try:
# --> 540     return self.layers[key[0]][key]  # type: ignore[index]
#     541 except (KeyError, IndexError, TypeError):
#     542     pass
#
# File ~/.local/lib/python3.12/site-packages/dask/highlevelgraph.py:348, in MaterializedLayer.__getitem__(self, k)
#     345 def __contains__(self, k):
#     346     return k in self.mapping
# --> 348 def __getitem__(self, k):
#     349     return self.mapping[k]
#     351 def __iter__(self):
#
# KeyboardInterrupt:

# %% [markdown]
# Get the elevation data for the d03 grid.

# %%
fs = s3fs.S3FileSystem(anon=True)
elevation_url = "s3://cadcat/wrf/cae/elevation_wrf.nc"
elevation = xr.open_dataset(fs.open(elevation_url), engine="h5netcdf")

# %% [markdown]
# Calculate the sea level pressure at each point and get the difference.

# %%
# Get SLP at points
slp_pt_1 = get_slp_at_point(
    psfc["psfc"], t2["t2"], q2["q2"], elevation["elevation"], gradient_point_1
).compute()
slp_pt_2 = get_slp_at_point(
    psfc["psfc"], t2["t2"], q2["q2"], elevation["elevation"], gradient_point_2
).compute()

# Get difference
slp_dif = slp_pt_1 - slp_pt_2

# Convert to dataset with name "slp_gradient"
slp_ds = slp_dif.to_dataset(name="slp_gradient")

export(slp_ds, "slp_gradient_2_0.nc", format="NetCDF", mode="local")

# %% [markdown]
# This figure demonstrates the resulting gradient for a single model for one year from the baseline warming level.

# %%
plot_sim = "WRF_UCLA_MIROC6_ssp370_1hr_d03_r1i1p1f1"

f, ax = plt.subplots(1, 2, figsize=(10, 4))
plt.rcParams.update(
    {
        "grid.color": "0.5",  # gray gridlines
        "grid.linestyle": "--",  # solid gridlines
        "grid.linewidth": 0.5,  # thin gridlines
    }
)


slp_ds["slp_gradient"].sel(warming_level=baseline_gwl, sim=plot_sim).plot(ax=ax[0])
ax[0].set_title(f"GWL {baseline_gwl}°C")
# ax[0].set_ylim([0, 70])
ax[0].set_xlim([slp_ds.time[0].data, slp_ds.time[-1].data])
ax[0].grid(True)

slp_ds["slp_gradient"].sel(warming_level=future_gwl, sim=plot_sim).plot(ax=ax[1])
ax[1].set_title(f"GWL {future_gwl}°C")
# ax[1].set_ylim([0, 70])
ax[1].set_xlim([slp_ds.time[0].data, slp_ds.time[-1].data])
ax[1].grid(True)

plt.suptitle(f"Sea level pressure gradient\n{plot_sim}")
plt.tight_layout()
plt.savefig(f"slp_gradient_by_gwl_{plot_sim}.png")
